# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

# %%
uploaded = files.upload()
image_name_1 = next(iter(uploaded))
room_light_image_path = '/content/' + image_name_1
print('Selected image 1:', room_light_image_path)
# Out:
#      <input type="file" id="files-df182a83-90da-4823-93a9-e9b2aa339fd6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-df182a83-90da-4823-93a9-e9b2aa339fd6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
gamma = 0.4

img_original = cv2.imread(room_light_image_path)
lookUpTable = np.empty((1, 256), np.uint8)

for i in range(256):
  lookUpTable[0, i] = np.clip(pow(i / 255.0, gamma) * 255.0, 0, 255)
out = cv2.LUT(img_original, lookUpTable)

plt.figure(figsize=[15, 5])
plt.subplot(121); plt.imshow(img_original[..., ::-1]); plt.title('Original')
plt.subplot(122); plt.imshow(out[..., ::-1]); plt.title('Gamma Correction')
plt.show()

# %%
uploaded = files.upload()
image_name_2 = next(iter(uploaded))
aa_image_path = '/content/' + image_name_2
print('Selected image 2:', aa_image_path)
# Out:
#      <input type="file" id="files-3ef9a205-a38f-49f5-80fa-6abb5ba87d4b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3ef9a205-a38f-49f5-80fa-6abb5ba87d4b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded = files.upload()
image_name_3 = next(iter(uploaded))
asalooye_image_path = '/content/' + image_name_3
print('Selected image 3:', asalooye_image_path)
# Out:
#      <input type="file" id="files-783567ef-1af6-4576-9d77-db0224af726e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-783567ef-1af6-4576-9d77-db0224af726e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
gamma = 0.4

img_original1 = cv2.imread(aa_image_path)
img_original2 = cv2.imread(asalooye_image_path)
output_linear1 = cv2.convertScaleAbs(img_original1, alpha=1.3, beta=40)
output_linear2 = cv2.convertScaleAbs(img_original2, alpha=1.3, beta=40)

lookUpTable = np.empty((1, 256), np.uint8)

for i in range(256):
  lookUpTable[0, i] = np.clip(pow(i / 255.0, gamma) * 255.0, 0, 255)

output_gammacorrected1 = cv2.LUT(img_original1, lookUpTable)
output_gammacorrected2 = cv2.LUT(img_original2, lookUpTable)

plt.figure(figsize=[17, 6])
plt.subplot(231); plt.imshow(img_original1[..., ::-1]); plt.title('Original')
plt.subplot(232); plt.imshow(output_linear1[..., ::-1]); plt.title('Linear')
plt.subplot(233); plt.imshow(output_gammacorrected1[..., ::-1]); plt.title('Gamma Correction')

plt.subplot(234); plt.imshow(img_original2[..., ::-1]); plt.title('Original')
plt.subplot(235); plt.imshow(output_linear2[..., ::-1]); plt.title('Linear')
plt.subplot(236); plt.imshow(output_gammacorrected2[..., ::-1]); plt.title('Gamma Correction')
plt.show()
